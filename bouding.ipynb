# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitannyanaidu/Bounding-Boxes/blob/main/bouding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load the image from the uploaded file
img_path = "/content/images.jpg"
img = cv2.imread(img_path)

# Get the dimensions of the image
height, width, _ = img.shape
print("Image width:", width)
print("Image height:", height)

# Example: Start with initial values and adjust
x = 58  # Move right
y = 55 # Move down
w = 117
h = 107

# Display the original image
cv2_imshow(img)

# Draw a green rectangle on the image
img_with_box = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the image with the rectangle
cv2_imshow(img_with_box)

cv2.destroyAllWindows()
# Out:
# Image width: 234
# Image height: 215
# <PIL.Image.Image image mode=RGB size=234x215>
# <PIL.Image.Image image mode=RGB size=234x215>
